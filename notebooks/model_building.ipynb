# %%
import pandas as pd

# %%
data_mat = pd.read_csv("./../student-mat.csv", sep=";")

# %%
data_por = pd.read_csv("./../student-por.csv", sep=";")

# %%
df = pd.concat([data_mat, data_por])

# %%
dfre
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df = df.drop(columns=["school", "sex", "address", "famsize", "Pstatus", "Medu", "Fedu", "Mjob", "Fjob", "reason", "guardian"])

# %%
df
# Out:
#      age  traveltime  studytime  failures schoolsup famsup paid activities  \
# 0     18           2          2         0       yes     no   no         no
# 1     17           1          2         0        no    yes   no         no
# 2     15           1          2         3       yes     no  yes         no
# 3     15           1          3         0        no    yes  yes        yes
# 4     16           1          2         0        no    yes  yes         no
# ..   ...         ...        ...       ...       ...    ...  ...        ...
# 644   19           1          3         1        no     no   no        yes
# 645   18           1          2         0        no    yes   no         no
# 646   18           2          2         0        no     no   no        yes
# 647   17           2          1         0        no     no   no         no
# 648   18           3          1         0        no     no   no         no
#
# ...

# %%
df["schoolsup"] = df["schoolsup"].map({"yes": 1, "no": 0})

# %%
df["famsup"] = df["famsup"].map({"yes": 1, "no": 0})

# %%
df["paid"] = df["paid"].map({"yes": 1, "no": 0})

# %%
df["activities"] = df["activities"].map({"yes": 1, "no": 0})

# %%
df["nursery"] = df["nursery"].map({"yes": 1, "no": 0})

# %%
df["higher"] = df["higher"].map({"yes": 1, "no": 0})

# %%
df["internet"] = df["internet"].map({"yes": 1, "no": 0})

# %%
df["romantic"] = df["romantic"].map({"yes": 1, "no": 0})

# %%
df.head()
# Out:
#    age  traveltime  studytime  failures  schoolsup  famsup  paid  activities  \
# 0   18           2          2         0          1       0     0           0
# 1   17           1          2         0          0       1     0           0
# 2   15           1          2         3          1       0     1           0
# 3   15           1          3         0          0       1     1           1
# 4   16           1          2         0          0       1     1           0
#
#    nursery  higher  ...  famrel  freetime  goout  Dalc  Walc  health  \
# 0        1       1  ...       4         3      4     1     1       3
# 1        0       1  ...       5         3      3     1     1       3
# 2        1       1  ...       4         3      2     2     3       3
# 3        1       1  ...       3         2      2     1     1       5
# 4        1       1  ...       4         3      2     1     2       5
#
#    absences  G1  G2  G3
# 0         6   5   6   6
# 1         4   5   5   6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1044 entries, 0 to 648
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         1044 non-null   int64
#  1   traveltime  1044 non-null   int64
#  2   studytime   1044 non-null   int64
#  3   failures    1044 non-null   int64
#  4   schoolsup   1044 non-null   int64
#  5   famsup      1044 non-null   int64
#  6   paid        1044 non-null   int64
#  7   activities  1044 non-null   int64
#  8   nursery     1044 non-null   int64
#  9   higher      1044 non-null   int64
#  10  internet    1044 non-null   int64
#  11  romantic    1044 non-null   int64
#  12  famrel      1044 non-null   int64
#  13  freetime    1044 non-null   int64
#  14  goout       1044 non-null   int64
#  15  Dalc        1044 non-null   int64
#  16  Walc        1044 non-null   int64
#  17  health      1044 non-null   int64
#  18  absences    1044 non-null   int64
# ...

# %%
df.corr()["G1"]
# Out:
# age          -0.124121
# traveltime   -0.121053
# studytime     0.211314
# failures     -0.374175
# schoolsup    -0.136877
# famsup       -0.013655
# paid         -0.038588
# activities    0.067962
# nursery       0.047878
# higher        0.271476
# internet      0.104772
# romantic     -0.055869
# famrel        0.036947
# freetime     -0.051985
# goout        -0.101163
# Dalc         -0.150943
# Walc         -0.142401
# health       -0.060478
# absences     -0.092425
# G1            1.000000
# G2            0.858739
# G3            0.809142
# Name: G1, dtype: float64
